# %%
# !pip install apache-airflow-providers-papermill
# Out:
# Requirement already satisfied: apache-airflow-providers-papermill in x:\anaconda\lib\site-packages (2.2.3)
# Requirement already satisfied: apache-airflow>=2.1.0 in x:\anaconda\lib\site-packages (from apache-airflow-providers-papermill) (2.3.2)
# Requirement already satisfied: papermill[all]>=1.2.1 in x:\anaconda\lib\site-packages (from apache-airflow-providers-papermill) (2.3.4)
# Requirement already satisfied: scrapbook[all] in x:\anaconda\lib\site-packages (from apache-airflow-providers-papermill) (0.5.0)
# Requirement already satisfied: pygments>=2.0.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.1.0)
# Requirement already satisfied: jinja2<3.1,>=2.10.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.11.3)
# Requirement already satisfied: python-nvd3>=0.15.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.15.0)
# Requirement already satisfied: cryptography>=0.9.3 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.4.8)
# Requirement already satisfied: cattrs!=1.7.*,~=1.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.10.0)
# Requirement already satisfied: flask-caching<2.0.0,>=1.5.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.13 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.13)
# Requirement already satisfied: flask-appbuilder==3.4.5 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.4.5)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (4.8.0)
# Requirement already satisfied: lazy-object-proxy in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.6.0)
# Requirement already satisfied: httpx in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.23.0)
# Requirement already satisfied: packaging>=14.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (21.0)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.0.0)
# Requirement already satisfied: lockfile>=0.12.2 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.12.2)
# Requirement already satisfied: apache-airflow-providers-ftp in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.1.2)
# Requirement already satisfied: pathspec~=0.9.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.9.0)
# Requirement already satisfied: blinker in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.4)
# Requirement already satisfied: tenacity>=6.2.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (8.0.1)
# Requirement already satisfied: markdown>=3.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.3.7)
# Requirement already satisfied: python-slugify>=5.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (5.0.2)
# Requirement already satisfied: croniter>=0.3.17 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.3.5)
# Requirement already satisfied: cron-descriptor>=1.2.24 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.24)
# Requirement already satisfied: markupsafe<2.1.0,>=1.1.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.1.1)
# Requirement already satisfied: pendulum>=2.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.1.2)
# Requirement already satisfied: jsonschema<5.0,>=3.2.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.2.0)
# Requirement already satisfied: connexion[flask,swagger-ui]>=2.10.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.13.1)
# Requirement already satisfied: tabulate>=0.7.5 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.8.9)
# Requirement already satisfied: alembic<2.0,>=1.5.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.8.0)
# Requirement already satisfied: rich>=12.4.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (12.4.4)
# Requirement already satisfied: python-daemon>=2.2.4 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.3 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.8.2)
# Requirement already satisfied: graphviz>=0.12 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.20)
# Requirement already satisfied: setproctitle>=1.1.8 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.3)
# Requirement already satisfied: werkzeug>=1.0.1,~=1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.0.1)
# Requirement already satisfied: apache-airflow-providers-http in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.1.2)
# Requirement already satisfied: flask-login<0.5,>=0.3 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.4.1)
# Requirement already satisfied: apache-airflow-providers-imap in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.2.3)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.0.1)
# Requirement already satisfied: flask<2.0,>=1.1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.1.2)
# Requirement already satisfied: unicodecsv>=0.14.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (4.2.0)
# Requirement already satisfied: itsdangerous<2.0,>=1.1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.1.0)
# Requirement already satisfied: psutil>=4.2.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (5.8.0)
# Requirement already satisfied: attrs<21.0,>=20.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (20.3.0)
# Requirement already satisfied: apache-airflow-providers-sqlite in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.1.3)
# Requirement already satisfied: dill>=0.2.2 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.3.5.1)
# Requirement already satisfied: flask-wtf<0.15,>=0.14.3 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.14.3)
# Requirement already satisfied: argcomplete>=1.10 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.0.0)
# Requirement already satisfied: sqlalchemy<1.4.10,>=1.4 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.4.9)
# Requirement already satisfied: flask-session<=0.4.0,>=0.3.1 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.4.0)
# Requirement already satisfied: pluggy>=1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.0.0)
# Requirement already satisfied: gunicorn>=20.1.0 in x:\anaconda\lib\site-packages (from apache-airflow>=2.1.0->apache-airflow-providers-papermill) (20.1.0)
# Requirement already satisfied: marshmallow-enum<2,>=1.5.1 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.5.1)
# Requirement already satisfied: email-validator<2,>=1.0.5 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.1)
# Requirement already satisfied: PyJWT<2.0.0,>=1.7.1 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.7.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.4.4)
# Requirement already satisfied: Flask-OpenID<2,>=1.2.5 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.3.0)
# Requirement already satisfied: click<9,>=6.7 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (8.0.3)
# Requirement already satisfied: marshmallow<4,>=3 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.16.0)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.38.2)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.26.1)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.5.1)
# Requirement already satisfied: Flask-Babel<3,>=1 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.0.0)
# Requirement already satisfied: apispec[yaml]<4,>=3.3 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.3.2)
# Requirement already satisfied: Flask-JWT-Extended<4,>=3.18 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.25.1)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.2.1)
# Requirement already satisfied: WTForms<3.0.0 in x:\anaconda\lib\site-packages (from flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.3.3)
# Requirement already satisfied: Mako in x:\anaconda\lib\site-packages (from alembic<2.0,>=1.5.1->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.0)
# Requirement already satisfied: PyYAML>=3.10 in x:\anaconda\lib\site-packages (from apispec[yaml]<4,>=3.3->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (6.0)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in x:\anaconda\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.5.1)
# Requirement already satisfied: clickclick<21,>=1.2 in x:\anaconda\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (20.10.2)
# Requirement already satisfied: requests<3,>=2.9.1 in x:\anaconda\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.26.0)
# Requirement already satisfied: swagger-ui-bundle<0.1,>=0.0.2 in x:\anaconda\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.0.9)
# Requirement already satisfied: cffi>=1.12 in x:\anaconda\lib\site-packages (from cryptography>=0.9.3->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.14.6)
# Requirement already satisfied: pycparser in x:\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.20)
# Requirement already satisfied: wrapt<2,>=1.10 in x:\anaconda\lib\site-packages (from deprecated>=1.2.13->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.12.1)
# Requirement already satisfied: dnspython>=1.15.0 in x:\anaconda\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.2.1)
# Requirement already satisfied: idna>=2.0.0 in x:\anaconda\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.2)
# Requirement already satisfied: Babel>=2.3 in x:\anaconda\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2.9.1)
# Requirement already satisfied: pytz in x:\anaconda\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2021.3)
# Requirement already satisfied: cachelib in x:\anaconda\lib\site-packages (from flask-caching<2.0.0,>=1.5.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.7.0)
# Requirement already satisfied: six in x:\anaconda\lib\site-packages (from Flask-JWT-Extended<4,>=3.18->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.16.0)
# Requirement already satisfied: python3-openid>=2.0 in x:\anaconda\lib\site-packages (from Flask-OpenID<2,>=1.2.5->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.2.0)
# Requirement already satisfied: setuptools>=3.0 in x:\anaconda\lib\site-packages (from gunicorn>=20.1.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in x:\anaconda\lib\site-packages (from jsonschema<5.0,>=3.2.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.18.0)
# Requirement already satisfied: importlib-metadata>=4.4 in x:\anaconda\lib\site-packages (from markdown>=3.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in x:\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown>=3.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in x:\anaconda\lib\site-packages (from packaging>=14.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.0.4)
# Requirement already satisfied: ansiwrap in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.8.4)
# Requirement already satisfied: nbformat>=5.1.2 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (5.1.3)
# Requirement already satisfied: nbclient>=0.2.0 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.5.3)
# Requirement already satisfied: entrypoints in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.3)
# Requirement already satisfied: tqdm>=4.32.2 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (4.62.3)
# Requirement already satisfied: pyarrow in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (8.0.0)
# Requirement already satisfied: azure-datalake-store>=0.0.30 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.0.52)
# Requirement already satisfied: black>=19.3b0 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (19.10b0)
# Requirement already satisfied: azure-storage-blob>=12.1.0 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (12.12.0)
# Requirement already satisfied: boto3 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.24.2)
# Requirement already satisfied: gcsfs>=0.2.0 in x:\anaconda\lib\site-packages (from papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2022.5.0)
# Requirement already satisfied: adal>=0.4.2 in x:\anaconda\lib\site-packages (from azure-datalake-store>=0.0.30->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.2.7)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in x:\anaconda\lib\site-packages (from azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.24.1)
# Requirement already satisfied: msrest>=0.6.21 in x:\anaconda\lib\site-packages (from azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.6.21)
# Requirement already satisfied: regex in x:\anaconda\lib\site-packages (from black>=19.3b0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2021.8.3)
# Requirement already satisfied: typed-ast>=1.4.0 in x:\anaconda\lib\site-packages (from black>=19.3b0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.4.3)
# Requirement already satisfied: appdirs in x:\anaconda\lib\site-packages (from black>=19.3b0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.4.4)
# Requirement already satisfied: toml>=0.9.4 in x:\anaconda\lib\site-packages (from black>=19.3b0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.10.2)
# Requirement already satisfied: google-auth-oauthlib in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.5.1)
# Requirement already satisfied: fsspec==2022.5.0 in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2022.5.0)
# Requirement already satisfied: aiohttp<4 in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (3.8.1)
# Requirement already satisfied: decorator>4.1.2 in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (5.1.0)
# Requirement already satisfied: google-auth>=1.2 in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.6.6)
# Requirement already satisfied: google-cloud-storage in x:\anaconda\lib\site-packages (from gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in x:\anaconda\lib\site-packages (from aiohttp<4->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in x:\anaconda\lib\site-packages (from google-auth>=1.2->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in x:\anaconda\lib\site-packages (from google-auth>=1.2->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in x:\anaconda\lib\site-packages (from google-auth>=1.2->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in x:\anaconda\lib\site-packages (from msrest>=0.6.21->azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in x:\anaconda\lib\site-packages (from msrest>=0.6.21->azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2021.10.8)
# Requirement already satisfied: isodate>=0.6.0 in x:\anaconda\lib\site-packages (from msrest>=0.6.21->azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.6.1)
# Requirement already satisfied: traitlets>=4.2 in x:\anaconda\lib\site-packages (from nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (5.1.0)
# Requirement already satisfied: jupyter-client>=6.1.5 in x:\anaconda\lib\site-packages (from nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (6.1.12)
# Requirement already satisfied: async-generator in x:\anaconda\lib\site-packages (from nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.10)
# Requirement already satisfied: nest-asyncio in x:\anaconda\lib\site-packages (from nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.5.1)
# Requirement already satisfied: tornado>=4.1 in x:\anaconda\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (6.1)
# Requirement already satisfied: pyzmq>=13 in x:\anaconda\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in x:\anaconda\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (4.8.1)
# Requirement already satisfied: pywin32>=1.0 in x:\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.5->nbclient>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (228)
# Requirement already satisfied: ipython-genutils in x:\anaconda\lib\site-packages (from nbformat>=5.1.2->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.2.0)
# Requirement already satisfied: pytzdata>=2020.1 in x:\anaconda\lib\site-packages (from pendulum>=2.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (2020.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in x:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.4.8)
# Requirement already satisfied: docutils in x:\anaconda\lib\site-packages (from python-daemon>=2.2.4->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.17.1)
# Requirement already satisfied: text-unidecode>=1.3 in x:\anaconda\lib\site-packages (from python-slugify>=5.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.3)
# Requirement already satisfied: defusedxml in x:\anaconda\lib\site-packages (from python3-openid>=2.0->Flask-OpenID<2,>=1.2.5->flask-appbuilder==3.4.5->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in x:\anaconda\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in x:\anaconda\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob>=12.1.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (3.2.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in x:\anaconda\lib\site-packages (from rich>=12.4.1->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in x:\anaconda\lib\site-packages (from sqlalchemy<1.4.10,>=1.4->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.1.1)
# Requirement already satisfied: textwrap3>=0.9.2 in x:\anaconda\lib\site-packages (from ansiwrap->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.9.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in x:\anaconda\lib\site-packages (from boto3->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.2 in x:\anaconda\lib\site-packages (from boto3->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.27.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in x:\anaconda\lib\site-packages (from boto3->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.0.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in x:\anaconda\lib\site-packages (from google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.3.0)
# Requirement already satisfied: google-resumable-media>=2.3.2 in x:\anaconda\lib\site-packages (from google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.3.3)
# Requirement already satisfied: protobuf in x:\anaconda\lib\site-packages (from google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (3.20.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in x:\anaconda\lib\site-packages (from google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (2.8.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in x:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.56.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in x:\anaconda\lib\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs>=0.2.0->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.3.0)
# Requirement already satisfied: httpcore<0.16.0,>=0.15.0 in x:\anaconda\lib\site-packages (from httpx->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.15.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in x:\anaconda\lib\site-packages (from httpx->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.5.0)
# Requirement already satisfied: sniffio in x:\anaconda\lib\site-packages (from httpx->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (1.2.0)
# Requirement already satisfied: anyio==3.* in x:\anaconda\lib\site-packages (from httpcore<0.16.0,>=0.15.0->httpx->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (3.6.1)
# Requirement already satisfied: h11<0.13,>=0.11 in x:\anaconda\lib\site-packages (from httpcore<0.16.0,>=0.15.0->httpx->apache-airflow>=2.1.0->apache-airflow-providers-papermill) (0.12.0)
# Requirement already satisfied: numpy>=1.16.6 in x:\anaconda\lib\site-packages (from pyarrow->papermill[all]>=1.2.1->apache-airflow-providers-papermill) (1.20.3)
# Requirement already satisfied: pandas in x:\anaconda\lib\site-packages (from scrapbook[all]->apache-airflow-providers-papermill) (1.3.4)
# Requirement already satisfied: ipython in x:\anaconda\lib\site-packages (from scrapbook[all]->apache-airflow-providers-papermill) (7.29.0)
# Requirement already satisfied: backcall in x:\anaconda\lib\site-packages (from ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.2.0)
# Requirement already satisfied: pickleshare in x:\anaconda\lib\site-packages (from ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in x:\anaconda\lib\site-packages (from ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.18.0)
# Requirement already satisfied: matplotlib-inline in x:\anaconda\lib\site-packages (from ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in x:\anaconda\lib\site-packages (from ipython->scrapbook[all]->apache-airflow-providers-papermill) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in x:\anaconda\lib\site-packages (from jedi>=0.16->ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.8.2)
# Requirement already satisfied: wcwidth in x:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->scrapbook[all]->apache-airflow-providers-papermill) (0.2.5)

# %%
from airflow import DAG
from airflow.operators.bash_operator import BashOperator
from datetime import datetime, timedelta
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_12072/703257808.py:2 DeprecationWarning: This module is deprecated. Please use `airflow.operators.bash`.

# %% [markdown]
# (a-b)^2-(b+c)*d+(b+c)(a-b)

# %%
# Following are defaults which can be overridden later on
args = {
    'owner': 'dimon',
    'start_date':datetime(2018, 11, 1),
    'provide_context':True
}

with DAG('Hello-world', description='Hello-world', schedule_interval='*/1 * * * *',  catchup=False, default_args=args) as dag: #0 * * * *   */1 * * * *
    t1 = BashOperator(
        task_id='task_1',
        provide_context=True,
        bash_command='echo "Hello World from Task 1"')

    t2 = BashOperator(
        task_id='task_2',
        bash_command='echo "Hello World from Task 2"')

    t3 = BashOperator(
        task_id='task_3',
        bash_command='echo "Hello World from Task 3"')

    t4 = BashOperator(
        task_id='task_4',
        bash_command='echo "Hello World from Task 4"')

    t1 >> t2
    t1 >> t3
    t2 >> t4
    t3 >> t4

# dag = DAG('Hello-world', default_args=default_args)

# # t1, t2, t3 and t4 are examples of tasks created using operators

# t1 = BashOperator(
#     task_id='task_1',
#     bash_command='echo "Hello World from Task 1"',
#     dag=dag)

# t2 = BashOperator(
#     task_id='task_2',
#     bash_command='echo "Hello World from Task 2"',
#     dag=dag)

# t3 = BashOperator(schedule_interval='0 * * * *',  catchup=False,
#     task_id='task_3',
#     bash_command='echo "Hello World from Task 3"',
#     dag=dag)

# t4 = BashOperator(
#     task_id='task_4',
#     bash_command='echo "Hello World from Task 4"',
#     dag=dag)

# t2.set_upstream(t1)
# t3.set_upstream(t1)
# t4.set_upstream(t2)
# t4.set_upstream(t3)
